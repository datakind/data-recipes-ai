# %% [markdown]
# # Introduction:
#
# In this notebook, we evaluate HYDE RAG to improve how the system searches for recipes/ memories in the recipe database.
#
# To achieve this, we will:
# 1) Replicate the current status quo of a simple similarity search of intents
# 2) Implement HYDE RAG
# 3) Have an LLM Service create a test-set of multiple variations to ask for a recipe/memory
# 4) Compare the two approaches using the test set of user inputs and corresponding intents as they're saved in the db

# %% [markdown]
# ## 1) Replicate the current status quo of a simple similarity search of intents

# %%
import utils.recipes as recipes
from dotenv import load_dotenv
import os
import langchain_community.vectorstores.pgvector

load_dotenv(dotenv_path='.env')
# Out:
# True

# %%
os.environ['POSTGRES_RECIPE_HOST'] = 'localhost'
os.environ['POSTGRES_RECIPE_PORT'] = '5435'

# %%
# Get the recipe
memory = recipes.check_recipe_memory(intent="get all recipes")
# Out:
# ======= Checking memory for intent: get all recipes
#
#  Score: 0.024769451503484974 ===> retrieve all recipes
#
#  Score: 0.024882707727358455 ===> retrieve all recipes
#
#  Score: 0.26250582300178316 ===> plot a scatterplot of food price movements and number of fatalities in TCD from 2008-01-01 using HDXData data, including regression line as an image
# ======= Checking recipe for intent: get all recipes
#
#  Score: 0.0 ===> get all recipes
#
#  Score: 5.066396355779546e-07 ===> get all recipes
#
#  Score: 0.24387583863364326 ===> provide a list of organizations providing food security for a region in a country
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# get all recipes
#
# Here are possible matches:
#
# 1. retrieve all recipes
# 2. retrieve all recipes
# 3. get all recipes
# 4. get all recipes
# 5. provide a list of organizations providing food security for a region in a country
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user's request 'get all recipes' matches exactly with the options provided in rows 3 and 4. Since only one match is allowed, we can choose either row 3 or row 4.", 'match_id': 3}
# AI Judge of match:  {'answer': 'yes', 'reason': "The user's request 'get all recipes' matches exactly with the options provided in rows 3 and 4. Since only one match is allowed, we can choose either row 3 or row 4.", 'match_id': 3}
#
#     MATCH!
# {'score': 0.0, 'content': 'get all recipes', 'metadata': {'mem_type': 'recipe', 'custom_id': '83ab2323-e9cc-42c5-bd2d-a68b76146a95'}}

# %%
print("Memory: ", memory)
# Out:
# Memory:  (True, {'score': 0.0, 'content': 'get all recipes', 'metadata': {'mem_type': 'recipe', 'custom_id': '83ab2323-e9cc-42c5-bd2d-a68b76146a95'}})

# %% [markdown]
# Ok, this seems to work well - similarity search has been performed, and we have a match that we can later compare to the matches of the HYDE RAG approach. We'll come back to this in step 4.

# %% [markdown]
# ## 2) Implement HYDE RAG
# Resource/ Template for the following implementation of HYDE RAG with Langchain can be found here: https://github.com/langchain-ai/langchain/blob/master/cookbook/hypothetical_document_embeddings.ipynb

# %%
from langchain.chains import HypotheticalDocumentEmbedder, LLMChain
from langchain.prompts import PromptTemplate
from langchain_openai import OpenAI, OpenAIEmbeddings
import langchain

# %%
langchain.debug = True

# %%
base_embeddings = OpenAIEmbeddings()
llm = OpenAI()

# %%
prompt_template = """Please provide the intent behind the question
Question: {question}"""
prompt = PromptTemplate(input_variables=["question"], template=prompt_template)
llm_chain = LLMChain(llm=llm, prompt=prompt)

# %%
#Make langchain produce multiple hypothetical documents and return the "average embedding vector" which is then used in the similarity search
multi_llm = OpenAI(n=4, best_of=4)

# %%
embeddings = HypotheticalDocumentEmbedder.from_llm(llm=multi_llm, base_embeddings=base_embeddings, custom_prompt=prompt
)

# %%
embeddings.llm_chain.prompt
# Out:
# PromptTemplate(input_variables=['question'], template='Please provide the intent behind the question\nQuestion: {question}')

# %%
result = embeddings.embed_query(
    "Get all data recipes"
)
# Out:
# [llm/start] [1:llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Please provide the intent behind the question\nQuestion: Get all data recipes"
#   ]
# }
# [llm/end] [1:llm:OpenAI] [1.48s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " from a specific category\n\nThe intent behind this question is to retrieve a list of all recipes that fall under a specific category, possibly for the purpose of finding new recipe ideas or planning a meal within a specific dietary or taste preference.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       },
#       {
#         "text": "\n\nThe intent behind this question is to retrieve a list of all recipes that contain data as an ingredient or focus on data as a main component. This could be for the purpose of finding new recipe ideas, organizing a collection of recipes, or researching the use of data in cooking.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       },
#       {
#         "text": "\n\nThe intent behind this question could be to gather a comprehensive list of recipes that can be used for cooking or meal preparation. It could also be to obtain a specific set of recipes that meet certain criteria, such as dietary restrictions or ingredients. The context and purpose of the request may vary, but the overall intention is to obtain a collection of recipes.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       },
#       {
#         "text": "\nThe intent behind this question is to retrieve a list or collection of all available data recipes, possibly for the purpose of selecting and using one for a specific task or project. ",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 208,
#       "total_tokens": 222,
#       "prompt_tokens": 14
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null
# }

# %%
result
# Out:
# [-0.003963554901276048,
#  0.0001621526115895668,
#  -0.002122585548110482,
#  -0.015043477452249631,
#  -0.004589223080396822,
#  0.00996447975182606,
#  0.00605746993887577,
#  -0.023337440133583073,
#  -0.03306297416431743,
#  -0.031428464733330205,
#  0.02266208225917085,
#  0.006007042359680604,
#  -0.013051493356350719,
#  -0.010353524768127982,
#  -0.003640041009947765,
#  0.030199656142065573,
#  0.030012374031058445,
#  0.0017984736931620836,
#  -0.002076831678103145,
#  -0.02239464366863579,
#  -0.011675049806057264,
#  -0.007058662402238336,
#  0.00705699694722246,
#  0.004177654226400219,
#  -0.006379032021249818,
#  -0.0028420827084948194,
#  0.011760271188024737,
#  -0.03333925288383012,
#  -0.020941041994311467,
#  0.011295024892354061,
#  0.012453470696965969,
#  0.006936936487015193,
#  -0.009950479851762813,
#  -0.02342300950819129,
#  -0.008105483396418905,
#  -0.008464955865482234,
#  -0.005033228625894349,
#  0.0011355808698169467,
#  0.006634366865040139,
#  -0.008031633708230894,
#  0.01721679550464395,
#  0.01738298933677345,
#  -0.004384474664152472,
#  -0.017952097026367728,
#  0.006285787862455211,
#  0.003701346417325071,
#  0.018511764645900423,
#  -0.015687203007708463,
#  -0.010581519742752498,
#  0.0006323695581645575,
#  0.03033783824421033,
#  0.012607740672960131,
#  -0.024860321609388517,
#  -0.016800952443834623,
#  0.002547525934734322,
#  0.019419296160540524,
#  -0.004998071272112662,
#  0.03191608193874539,
#  0.007946826739069901,
#  -0.0008626909826822738,
#  0.0070013491456117636,
#  0.04360774992499124,
#  -0.011958066856857295,
#  9.762513829561807e-05,
#  0.0056369927585348915,
#  -0.015522182584304673,
#  0.005990932122406147,
#  0.019226585526502186,
#  0.0010220134058228515,
#  0.017167998125901193,
#  0.01185081310831647,
#  0.012401164330921123,
#  -0.012633476871860366,
#  -0.004426512520236476,
#  -0.010819027430371593,
#  -0.028003142735718807,
#  -0.01813827789488045,
#  0.014278457808985567,
#  -0.021612699673640854,
#  0.00036876103182189777,
#  -0.004034216958383274,
#  0.01454318199689529,
#  -0.0025686864784884977,
#  0.030414170210705558,
#  0.00046629045194915395,
#  -0.009551497664654247,
#  -0.008716855748580568,
#  0.008350364216003584,
#  0.004039101003776791,
#  0.003291556536544515,
#  -0.01546065031793717,
#  0.003471665966987841,
#  -0.020821697476646542,
#  -0.0075394065758112505,
#  -0.025558605445452468,
#  -0.011599184126551422,
#  -0.023537145481713616,
#  0.01280014249814654,
#  0.010722296859907741,
#  -0.02749574436082432,
#  -0.029054771785033857,
#  0.007085409801188932,
#  0.012166971431875864,
#  -0.007134949723581657,
#  0.001413073349995342,
#  0.21167779360694053,
#  -0.004538999118866438,
#  -0.02032548078830801,
#  0.025762693168998246,
#  -0.004057013529890224,
#  0.005354040666271434,
#  0.00858252254158563,
#  -0.0005231861732692302,
#  -0.01648315729913268,
#  0.0056758845520086965,
#  0.012025779543265027,
#  -0.005453540439820426,
#  -0.01030556448678905,
#  0.0007718905670011711,
#  0.0025077324866515077,
#  0.0043389431307788474,
#  -0.023543433005583595,
#  -0.026076419380105322,
#  -0.0013567189303483986,
#  -0.01556547169007148,
#  0.026834776649633924,
#  0.024770186443855854,
#  -0.0031685090143517484,
#  -0.009162366427011535,
#  0.0350936353811735,
#  0.018612179077033147,
#  0.0184672098549135,
#  0.009756330004523821,
#  0.027888623643957156,
#  0.006430825681570147,
#  -0.002380861734783137,
#  -0.012131908840169391,
#  0.002351655972760685,
#  0.009198653677599738,
#  0.014027398849574478,
#  0.0006627616262306405,
#  0.013320036687431236,
#  -0.017351020686443126,
#  0.03057680430225678,
#  0.009738309553057623,
#  -0.0005528178840981373,
#  -0.0025592851355041224,
#  0.020231258806468606,
#  -0.01541450943302704,
#  0.0075389798559267664,
#  0.0006001360271715218,
#  ...]

# %%
def check_recipe_memory_from_hyde(intent, hyde_vector, debug=True):
    """
    Check the memory for a given intent.

    Args:
        intent (str): The intent to search for in the memory.
        debug (bool, optional): If True, print debug information. Default is True.

    Returns:
        dict: A dictionary containing the score, content, and metadata of the best match found in the memory.
            If no match is found, the dictionary values will be None.
    """

    global db
    if db is None:
        db = recipes.initialize_vector_db()

    # First do semantic search across memories and recipies
    matches = []
    for mem_type in ["memory", "recipe"]:
        if debug:
            print(f"======= Checking {mem_type} for intent: {intent}")
        docs = db[mem_type].similarity_search_with_score_by_vector(embedding=hyde_vector)
        #print all docs and scores
        for d in docs:
            score = d[1]
            content = d[0].page_content
            metadata = d[0].metadata
            if debug:
                print("\n", f"Score: {score} ===> {content}")

            if d[1] < recipes.similarity_cutoff[mem_type]:
                matches.append(d)

    r = {"score": None, "content": None, "metadata": None}
    result_found = False

    # No matches, no point calling the AI
    if len(matches) == 0:
        return result_found, r

    # Build a list for the AI judge to review
    match_list = ""
    for i, d in enumerate(matches):
        match_list += f"{i+1}. {d[0].page_content}\n"

    ai_memory_judge_prompt = recipes.environment.get_template("ai_memory_judge_prompt.jinja2")
    prompt = ai_memory_judge_prompt.render(
        user_input=intent, possible_matches=match_list
    )
    print(prompt)
    response = call_llm("", prompt)
    print(response)
    if "content" in response:
        response = response["content"]
    if isinstance(response, str):
        response = json.loads(response)
    if debug:
        print("AI Judge of match: ", response, "\n")
    if response["answer"].lower() == "yes":
        print("    MATCH!")
        match_id = response["match_id"]
        d = matches[int(match_id) - 1]
        score = d[1]
        content = d[0].page_content
        metadata = d[0].metadata
        r["score"] = score
        r["content"] = content
        r["metadata"] = metadata
        result_found = True
    print(r)
    return result_found, r

# %%
from utils.llm import call_llm, get_models
db = recipes.initialize_vector_db()

# %%
check_recipe_memory_from_hyde(intent="How much does my dog pearl weigh?", hyde_vector=result)
# Out:
# ======= Checking memory for intent: How much does my dog pearl weigh?
#
#  Score: 0.12342860351781382 ===> retrieve all recipes
#
#  Score: 0.12352695997777052 ===> retrieve all recipes
#
#  Score: 0.24628961364633273 ===> plot a scatterplot of food price movements and number of fatalities in TCD from 2008-01-01 using HDXData data, including regression line as an image
#
#  Score: 0.24628961364633273 ===> plot a scatterplot of food price movements and number of fatalities in TCD from 2008-01-01 using HDXData data, including regression line as an image
# ======= Checking recipe for intent: How much does my dog pearl weigh?
#
#  Score: 0.11924049106822643 ===> get all recipes
#
#  Score: 0.11924412668807893 ===> get all recipes
#
#  Score: 0.21676857443562647 ===> provide a list of organizations providing food security for a region in a country
#
#  Score: 0.2391359424848799 ===> plot a scatterplot of food price movements and number of fatalities by country using HDXData data, including regression line as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# How much does my dog pearl weigh?
#
# Here are possible matches:
#
# 1. retrieve all recipes
# 2. retrieve all recipes
# 3. get all recipes
# 4. get all recipes
# 5. provide a list of organizations providing food security for a region in a country
# 6. plot a scatterplot of food price movements and number of fatalities by country using HDXData data, including regression line as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# [llm/start] [1:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: \nHuman: \n\nYou are an AI judge that looks at matches for the user's request and decides if they are a match or not. \n\nYou cannot choose more than ONE match.\n\nYou have specific memories you can match on, as well as generic skills that might be what the user needs.\n\nFor example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a \nmemory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match\nlike this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example\n'plot a scatter graph of prices in a country'.\n\nKey points to consider:\n\n- 'metadata' can relate to user questions about available data\n- If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match\n- 'Plot population pyramids' means the same as 'plot a pyramid plot'\n\nExamples of Matches:\n\nUser intent: generate a line chart of Maize prices by year for 2013-2023 for Chad\nMatch: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image\nReason: There is a general skill which can be used for the user's request\n\nUser intent: plot population pyramids for chad\nMatch: plot population pyramids for Chad\nReason: The user asked for exactly this, sample plot, same country\n\nExamples that are NOT matches::\n\nUser intent: plot a map of population by state in Haiti\nMatch: I would like a plot of population by state in Mali\nReason: The user asked for Haiti, not Mali\n\nUser intent: give me a plot of population in Chad\nMatch: plot population pyramids for Chad\nReason: The user asked for a general plot of population but didn't specify a plot type\n\nThe user asked for this:\n\nHow much does my dog pearl weigh?\n\nHere are possible matches:\n\n1. retrieve all recipes\n2. retrieve all recipes\n3. get all recipes\n4. get all recipes\n5. provide a list of organizations providing food security for a region in a country\n6. plot a scatterplot of food price movements and number of fatalities by country using HDXData data, including regression line as an image\n\n\nDo any in the list match the user's intent?\n\nPlease respond with a JSON file of format ...\n\n{\n    \"answer\": <yes or no>,\n    \"reason\": <content>,\n    \"match_id\": <The number of the matching row in the list. Set to '' if no match>\n}"
#   ]
# }
# [llm/end] [1:llm:ChatOpenAI] [1.32s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "```json\n{\n    \"answer\": \"no\",\n    \"reason\": \"None of the possible matches relate to the user's request about the weight of their dog. The provided matches are all related to recipes, food security, and plotting food price movements, which are not relevant to the user's question.\",\n    \"match_id\": \"\"\n}\n```",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "```json\n{\n    \"answer\": \"no\",\n    \"reason\": \"None of the possible matches relate to the user's request about the weight of their dog. The provided matches are all related to recipes, food security, and plotting food price movements, which are not relevant to the user's question.\",\n    \"match_id\": \"\"\n}\n```",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 68,
#       "prompt_tokens": 570,
#       "total_tokens": 638
#     },
#     "model_name": "gpt-4o",
#     "system_fingerprint": "fp_ce0793330f"
#   },
#   "run": null
# }
# {'answer': 'no', 'reason': "None of the possible matches relate to the user's request about the weight of their dog. The provided matches are all related to recipes, food security, and plotting food price movements, which are not relevant to the user's question.", 'match_id': ''}
# AI Judge of match:  {'answer': 'no', 'reason': "None of the possible matches relate to the user's request about the weight of their dog. The provided matches are all related to recipes, food security, and plotting food price movements, which are not relevant to the user's question.", 'match_id': ''}
#
# {'score': None, 'content': None, 'metadata': None}
# (False, {'score': None, 'content': None, 'metadata': None})

# %% [markdown]
# Generally, this works well, but we now have to string everything together so that:
# - Multiple pseudo documents are created based on the user input
# - An average embedding vector for the pseudo documents is created
# - The original intent, together with the embedding vector is passed into the check_recipe_memory_from_hyde function
# - The output of the function is captured

# %%
def check_recipe_memory_from_hyde_workflow(user_input):
    average_embedding_vector = embeddings.embed_query(user_input)
    return check_recipe_memory_from_hyde(intent=user_input, hyde_vector=average_embedding_vector, debug=False)

# %%
langchain.debug = False

# %%
check_recipe_memory_from_hyde_workflow("Get all recipes")
# Out:
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# How much does my dog pearl weigh?
#
# Here are possible matches:
#
# 1. get all recipes
# 2. get all recipes
# 3. plot a line chart of commodity prices monthly relative change for a country from 2008-01-01 using HDX data as an image
# 4. plot a line chart of commodity prices monthly relative change for a country from 2008-01-01 using HDX data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'no', 'reason': "None of the possible matches relate to the user's request about the weight of their dog. The provided matches are about recipes and plotting commodity prices, which are unrelated to the user's intent.", 'match_id': ''}
# {'score': None, 'content': None, 'metadata': None}
# (False, {'score': None, 'content': None, 'metadata': None})

# %% [markdown]
# ## 3) Have an LLM Service create a test-set of multiple variations to ask for a recipe/memory
#
# The test set has been created by Claude 3.5 Sonnet with the following prompt:
#
# I'm testing the following application: A Chatbot used by humanitarian workers that can give answers to certain user questions. Each answer, commonly referred to as data recipes or memories, is stored in a database with an intent column and an actual answer. In my test, I want to specifically test the matching of actual user input to the correct "intent column" (and thus the answer) - i.e. the semantic search. Since humanitarian workers might use different jargon and don't necessarily know the data structure, they're input to ask for certain things might be very different from the intent as it's stored in the database.
# Your job is to, for each intent in the following list, create 10 ways how humanitarian users could ask for it. The output should be a downloadable csv file with "question" (that you generated) and "intent" (as I've provided):
#
# List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
# provide a text summary of metadata for Wadi Fira using HAPI data as text
#
# plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
#
# plot a scatterplot of food price movements and number of fatalities in TCD from 2008-01-01 using HDXData data, including regression line as an image
#
# plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
#
# create a sankey plot of refugee migration by country for Kenya using HAPI data as an image
#
# plot a map of IPC phase 3 data by admin_1 in Chad using HDX data as an image
#
# provide a list of organizations providing food security in Wadi Fira, Chad
#
# plot a map of population by admin1 for Haiti using HAPI data as an image
#
# plot population pyramids by age for Chad using HDX data as an image
#
# plot a scatterplot of food price movements and number of fatalities in TCD from 2008-01-01 using HDXData data, including regression line as an image
#
# plot a line chart of fatalities by month for Chad using HDX data as an image
#
# provide the total population of Mali using HDX data as text
#
# retrieve all recipes
#
# plot a line chart of conflict events by month for Chad using HDX data as an image
#
# retrieve all recipes
#
# plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
#
# And the output hase been saved as as test_cases_similarity_search_claude_35_sonnet in the tests folder to be used in the following side-by-side comparison

# %% [markdown]
# ## 4) Compare the two approaches using the test set of user inputs and corresponding intents as they're saved in the db

# %%
import pandas as pd

# %%
# load the test file
test_cases = pd.read_csv("./tests/test_cases_similarity_search_claude_35_sonnet.csv")
test_cases.head(3)
# Out:
#                                             question  \
# 0  Which NGOs are active in the most food-insecur...
# 1  Can you show me the main humanitarian actors i...
# 2  What organizations are working in Chad's hunge...
#
#                                     intent as per db
# 0  List organizations in the top 3 states by popu...
# 1  List organizations in the top 3 states by popu...
# 2  List organizations in the top 3 states by popu...

# %%
test_evaluation = test_cases.copy()

# %%
# Apply the function to the 'input' column and create new columns for the results
test_evaluation[['result_legacy_match', 'result_legacy_details']] = test_evaluation['question'].apply(lambda x: pd.Series(recipes.check_recipe_memory(intent=x)))
test_evaluation[['result_hyde_match', 'result_hyde_details']] = test_evaluation['question'].apply(lambda x: pd.Series(check_recipe_memory_from_hyde_workflow(user_input=x)))
# Out:
# ======= Checking memory for intent: Which NGOs are active in the most food-insecure regions of Chad?
#
#  Score: 0.13045043271940282 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.18325207183515335 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.21742968715098365 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: Which NGOs are active in the most food-insecure regions of Chad?
#
#  Score: 0.1391969662665321 ===> provide a list of organizations providing food security for a region in a country
#
#  Score: 0.2178829805150282 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.2178829805150282 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Which NGOs are active in the most food-insecure regions of Chad?
#
# Here are possible matches:
#
# 1. provide a list of organizations providing food security in Wadi Fira, Chad
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. provide a list of organizations providing food security for a region in a country
# 4. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user asked for NGOs active in the most food-insecure regions of Chad. The closest match is 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', which provides information on organizations in highly food-insecure regions (IPC Phase 3+).", 'match_id': 2}
# AI Judge of match:  {'answer': 'yes', 'reason': "The user asked for NGOs active in the most food-insecure regions of Chad. The closest match is 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', which provides information on organizations in highly food-insecure regions (IPC Phase 3+).", 'match_id': 2}
#
#     MATCH!
# {'score': 0.18325207183515335, 'content': 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', 'metadata': {'mem_type': 'memory', 'custom_id': '038c84df-9cc4-432c-a9b9-0e0b784c5af0'}}
# ======= Checking memory for intent: Can you show me the main humanitarian actors in Chad's worst-affected areas?
#
#  Score: 0.1800716626686485 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.18983367802694717 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
#
#  Score: 0.18983367802694717 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: Can you show me the main humanitarian actors in Chad's worst-affected areas?
#
#  Score: 0.1978397133541392 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.1978397133541392 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.21351411100969575 ===> provide a list of organizations providing food security for a region in a country
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Can you show me the main humanitarian actors in Chad's worst-affected areas?
#
# Here are possible matches:
#
# 1. provide a list of organizations providing food security in Wadi Fira, Chad
# 2. plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# 3. plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# 4. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 6. provide a list of organizations providing food security for a region in a country
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'no', 'reason': "None of the provided matches specifically address the user's request for the main humanitarian actors in Chad's worst-affected areas. The closest matches are related to specific regions or sectors, but they do not cover the broader scope of 'worst-affected areas' in Chad.", 'match_id': ''}
# AI Judge of match:  {'answer': 'no', 'reason': "None of the provided matches specifically address the user's request for the main humanitarian actors in Chad's worst-affected areas. The closest matches are related to specific regions or sectors, but they do not cover the broader scope of 'worst-affected areas' in Chad.", 'match_id': ''}
#
# {'score': None, 'content': None, 'metadata': None}
# ======= Checking memory for intent: What organizations are working in Chad's hunger hotspots?
#
#  Score: 0.11955091939893792 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.16283161418625058 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.19809296108399788 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: What organizations are working in Chad's hunger hotspots?
#
#  Score: 0.14723224325370876 ===> provide a list of organizations providing food security for a region in a country
#
#  Score: 0.20758869738443497 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.20758869738443497 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# What organizations are working in Chad's hunger hotspots?
#
# Here are possible matches:
#
# 1. provide a list of organizations providing food security in Wadi Fira, Chad
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# 4. provide a list of organizations providing food security for a region in a country
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 6. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user's request is to know about organizations working in Chad's hunger hotspots. The closest match is 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data' as it provides information about organizations in critical areas of Chad, which aligns with the user's intent.", 'match_id': 2}
# AI Judge of match:  {'answer': 'yes', 'reason': "The user's request is to know about organizations working in Chad's hunger hotspots. The closest match is 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data' as it provides information about organizations in critical areas of Chad, which aligns with the user's intent.", 'match_id': 2}
#
#     MATCH!
# {'score': 0.16283161418625058, 'content': 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', 'metadata': {'mem_type': 'memory', 'custom_id': '038c84df-9cc4-432c-a9b9-0e0b784c5af0'}}
# ======= Checking memory for intent: Give me a rundown of NGOs in Chad's top 3 food crisis zones
#
#  Score: 0.13615645601227877 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.17323503813325902 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.20524601905071482 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: Give me a rundown of NGOs in Chad's top 3 food crisis zones
#
#  Score: 0.14987560513600573 ===> provide a list of organizations providing food security for a region in a country
#
#  Score: 0.21240248458339783 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.21240248458339783 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Give me a rundown of NGOs in Chad's top 3 food crisis zones
#
# Here are possible matches:
#
# 1. provide a list of organizations providing food security in Wadi Fira, Chad
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. provide a list of organizations providing food security for a region in a country
# 4. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user asked for a rundown of NGOs in Chad's top 3 food crisis zones, which aligns with the request to list organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data. Both requests focus on identifying organizations in critical food crisis areas in Chad.", 'match_id': 2}
# AI Judge of match:  {'answer': 'yes', 'reason': "The user asked for a rundown of NGOs in Chad's top 3 food crisis zones, which aligns with the request to list organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data. Both requests focus on identifying organizations in critical food crisis areas in Chad.", 'match_id': 2}
#
#     MATCH!
# {'score': 0.17323503813325902, 'content': 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', 'metadata': {'mem_type': 'memory', 'custom_id': '038c84df-9cc4-432c-a9b9-0e0b784c5af0'}}
# ======= Checking memory for intent: Who's operating in Chad's most severe IPC Phase 3+ regions?
#
#  Score: 0.11493902028333902 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.17228393719887958 ===> plot a map of IPC phase 3 data by admin_1 in Chad using HDX data as an image
#
#  Score: 0.21684088907727028 ===> provide a list of organizations providing food security in Wadi Fira, Chad
# ======= Checking recipe for intent: Who's operating in Chad's most severe IPC Phase 3+ regions?
#
#  Score: 0.1618393370200374 ===> List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
#
#  Score: 0.22820799182605656 ===> plot a map of IPC phase data by admin_1 using HDX data as an image
#
#  Score: 0.2442730970057133 ===> provide a list of organizations providing food security for a region in a country
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Who's operating in Chad's most severe IPC Phase 3+ regions?
#
# Here are possible matches:
#
# 1. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 2. plot a map of IPC phase 3 data by admin_1 in Chad using HDX data as an image
# 3. List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
# 4. plot a map of IPC phase data by admin_1 using HDX data as an image
# 5. provide a list of organizations providing food security for a region in a country
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user's request is to identify organizations operating in Chad's most severe IPC Phase 3+ regions. The closest match is 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data' as it directly addresses the user's need for information about organizations in IPC Phase 3+ regions in Chad.", 'match_id': 1}
# AI Judge of match:  {'answer': 'yes', 'reason': "The user's request is to identify organizations operating in Chad's most severe IPC Phase 3+ regions. The closest match is 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data' as it directly addresses the user's need for information about organizations in IPC Phase 3+ regions in Chad.", 'match_id': 1}
#
#     MATCH!
# {'score': 0.11493902028333902, 'content': 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', 'metadata': {'mem_type': 'memory', 'custom_id': '038c84df-9cc4-432c-a9b9-0e0b784c5af0'}}
# ======= Checking memory for intent: What's the NGO presence in Chad's highest food insecurity areas?
#
#  Score: 0.13819250973584596 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.1883432079313362 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.21586911110785556 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: What's the NGO presence in Chad's highest food insecurity areas?
#
#  Score: 0.15188891600899035 ===> provide a list of organizations providing food security for a region in a country
#
#  Score: 0.2230252293378333 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.2230252293378333 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# What's the NGO presence in Chad's highest food insecurity areas?
#
# Here are possible matches:
#
# 1. provide a list of organizations providing food security in Wadi Fira, Chad
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. provide a list of organizations providing food security for a region in a country
# 4. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user asked for NGO presence in Chad's highest food insecurity areas, which aligns with listing organizations in the top 3 states by population in IPC Phase 3+ in Chad.", 'match_id': 2}
# AI Judge of match:  {'answer': 'yes', 'reason': "The user asked for NGO presence in Chad's highest food insecurity areas, which aligns with listing organizations in the top 3 states by population in IPC Phase 3+ in Chad.", 'match_id': 2}
#
#     MATCH!
# {'score': 0.1883432079313362, 'content': 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', 'metadata': {'mem_type': 'memory', 'custom_id': '038c84df-9cc4-432c-a9b9-0e0b784c5af0'}}
# ======= Checking memory for intent: Show me the humanitarian landscape in Chad's top 3 IPC 3+ states
#
#  Score: 0.10655348222810246 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.17689972061516368 ===> plot a map of IPC phase 3 data by admin_1 in Chad using HDX data as an image
#
#  Score: 0.18984644473514145 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: Show me the humanitarian landscape in Chad's top 3 IPC 3+ states
#
#  Score: 0.15380475155030016 ===> List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
#
#  Score: 0.1950269225223692 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.1950269225223692 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Show me the humanitarian landscape in Chad's top 3 IPC 3+ states
#
# Here are possible matches:
#
# 1. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 2. plot a map of IPC phase 3 data by admin_1 in Chad using HDX data as an image
# 3. plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# 4. List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 6. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user's request is to show the humanitarian landscape in Chad's top 3 IPC 3+ states. The closest match is 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', which aligns with the user's intent to understand the humanitarian landscape in those specific states.", 'match_id': 1}
# AI Judge of match:  {'answer': 'yes', 'reason': "The user's request is to show the humanitarian landscape in Chad's top 3 IPC 3+ states. The closest match is 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', which aligns with the user's intent to understand the humanitarian landscape in those specific states.", 'match_id': 1}
#
#     MATCH!
# {'score': 0.10655348222810246, 'content': 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data', 'metadata': {'mem_type': 'memory', 'custom_id': '038c84df-9cc4-432c-a9b9-0e0b784c5af0'}}
# ======= Checking memory for intent: Which aid groups are tackling the worst hunger in Chad?
#
#  Score: 0.14413258030399745 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.1960993292272476 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.21328246593475342 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: Which aid groups are tackling the worst hunger in Chad?
#
#  Score: 0.175965358259357 ===> provide a list of organizations providing food security for a region in a country
#
#  Score: 0.224601149559021 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.224601149559021 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Which aid groups are tackling the worst hunger in Chad?
#
# Here are possible matches:
#
# 1. provide a list of organizations providing food security in Wadi Fira, Chad
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. provide a list of organizations providing food security for a region in a country
# 4. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user's request is about aid groups tackling hunger in Chad, which aligns with the request for a list of organizations providing food security in Wadi Fira, Chad.", 'match_id': 1}
# AI Judge of match:  {'answer': 'yes', 'reason': "The user's request is about aid groups tackling hunger in Chad, which aligns with the request for a list of organizations providing food security in Wadi Fira, Chad.", 'match_id': 1}
#
#     MATCH!
# {'score': 0.14413258030399745, 'content': 'provide a list of organizations providing food security in Wadi Fira, Chad', 'metadata': {'mem_type': 'memory', 'custom_id': '570e26ee-3ff7-438f-b2d3-feb826b956b4'}}
# ======= Checking memory for intent: Breakdown of organizations in Chad's most food-insecure regions
#
#  Score: 0.14052909564087834 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.1658561478300017 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.21095237764574193 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: Breakdown of organizations in Chad's most food-insecure regions
#
#  Score: 0.14008214652293138 ===> provide a list of organizations providing food security for a region in a country
#
#  Score: 0.20786950611679234 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#  Score: 0.20786950611679234 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Breakdown of organizations in Chad's most food-insecure regions
#
# Here are possible matches:
#
# 1. provide a list of organizations providing food security in Wadi Fira, Chad
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. provide a list of organizations providing food security for a region in a country
# 4. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'no', 'reason': "None of the provided matches specifically address the user's request for a breakdown of organizations in Chad's most food-insecure regions. The closest matches either focus on specific regions or provide general information about organizations without focusing on food insecurity.", 'match_id': ''}
# AI Judge of match:  {'answer': 'no', 'reason': "None of the provided matches specifically address the user's request for a breakdown of organizations in Chad's most food-insecure regions. The closest matches either focus on specific regions or provide general information about organizations without focusing on food insecurity.", 'match_id': ''}
#
# {'score': None, 'content': None, 'metadata': None}
# ======= Checking memory for intent: Who's responding to the top 3 hunger crises in Chad?
#
#  Score: 0.16457924209460628 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.17077403242742673 ===> List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
#
#  Score: 0.22563284635543823 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: Who's responding to the top 3 hunger crises in Chad?
#
#  Score: 0.19278107924573995 ===> provide a list of organizations providing food security for a region in a country
#
#  Score: 0.2188034988875931 ===> List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
#
#  Score: 0.23638916015625 ===> plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Who's responding to the top 3 hunger crises in Chad?
#
# Here are possible matches:
#
# 1. provide a list of organizations providing food security in Wadi Fira, Chad
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. provide a list of organizations providing food security for a region in a country
# 4. List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
# 5. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'no', 'reason': "None of the provided matches specifically address the user's request for information on who is responding to the top 3 hunger crises in Chad. The closest matches either focus on food security in specific regions or list organizations by population in IPC Phase 3+ states, but they do not directly address the top 3 hunger crises.", 'match_id': ''}
# AI Judge of match:  {'answer': 'no', 'reason': "None of the provided matches specifically address the user's request for information on who is responding to the top 3 hunger crises in Chad. The closest matches either focus on food security in specific regions or list organizations by population in IPC Phase 3+ states, but they do not directly address the top 3 hunger crises.", 'match_id': ''}
#
# {'score': None, 'content': None, 'metadata': None}
# ======= Checking memory for intent: What do we know about Wadi Fira?
#
#  Score: 0.1835964918136075 ===> provide a list of organizations providing food security in Wadi Fira, Chad
#
#  Score: 0.18936154969194618 ===> provide a text summary of metadata for Wadi Fira using HAPI data as text
#
#  Score: 0.21061124611890614 ===> plot a bar chart of humanitarian organizations in Wadi Fira by sector using Humanitarian Data Exchange data as an image
# ======= Checking recipe for intent: What do we know about Wadi Fira?
#
#  Score: 0.2678618388505314 ===> create a sankey plot of refugee migration by country for Kenya using HAPI data as an image
#
#  Score: 0.2678618388505314 ===> create a sankey plot of refugee migration by country for Kenya using HAPI data as an image
#
#  Score: 0.2728746912256791 ===> provide a text summary of metadata by subnational region using HAPI data as text
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# ...
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Graph Chad's age distribution
#
# Here are possible matches:
#
# 1. plot population pyramids by age for Chad using HDX data as an image
# 2. plot a line chart of fatalities by month for Chad using HDX data as an image
# 3. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 4. plot population pyramids by age for a country using HDX data as an image
# 5. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
# 6. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
# 7. plot a bar chart of humanitarian organizations by sector for a given region using Humanitarian Data Exchange data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user asked for a graph of Chad's age distribution, which is best matched by a population pyramid. The first option specifically mentions plotting population pyramids by age for Chad using HDX data as an image.", 'match_id': 1}
#     MATCH!
# {'score': 0.12611817376732903, 'content': 'plot population pyramids by age for Chad using HDX data as an image', 'metadata': {'mem_type': 'memory', 'custom_id': '70d84687-302e-47ac-9019-28921bc20380'}}
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# What does Chad's population pyramid look like?
#
# Here are possible matches:
#
# 1. plot population pyramids by age for Chad using HDX data as an image
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. plot a line chart of fatalities by month for Chad using HDX data as an image
# 4. plot population pyramids by age for a country using HDX data as an image
# 5. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
# 6. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
# 7. List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': 'The user asked for a population pyramid for Chad, and option 1 matches this request exactly by plotting population pyramids by age for Chad using HDX data as an image.', 'match_id': 1}
#     MATCH!
# {'score': 0.13137604787027934, 'content': 'plot population pyramids by age for Chad using HDX data as an image', 'metadata': {'mem_type': 'memory', 'custom_id': '70d84687-302e-47ac-9019-28921bc20380'}}
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Can you create an age structure diagram for Chad?
#
# Here are possible matches:
#
# 1. plot population pyramids by age for Chad using HDX data as an image
# 2. plot a line chart of fatalities by month for Chad using HDX data as an image
# 3. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 4. create a sankey plot of refugee migration by country for Kenya using HAPI data as an image
# 5. plot population pyramids by age for a country using HDX data as an image
# 6. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
# 7. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
# 8. create a sankey plot of refugee migration by country for Kenya using HAPI data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': 'The user asked for an age structure diagram for Chad, which is synonymous with a population pyramid. The first option matches this request exactly, specifying the same country and plot type.', 'match_id': '1'}
#     MATCH!
# {'score': 0.11521589963844947, 'content': 'plot population pyramids by age for Chad using HDX data as an image', 'metadata': {'mem_type': 'memory', 'custom_id': '70d84687-302e-47ac-9019-28921bc20380'}}
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# I want to see the generational makeup of Chad's population
#
# Here are possible matches:
#
# 1. plot population pyramids by age for Chad using HDX data as an image
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. plot population pyramids by age for a country using HDX data as an image
# 4. List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
# 5. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
# 6. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'yes', 'reason': "The user wants to see the generational makeup of Chad's population, which can be visualized using a population pyramid. The first option specifically mentions plotting population pyramids by age for Chad using HDX data, which directly matches the user's request.", 'match_id': 1}
#     MATCH!
# {'score': 0.14900480152547457, 'content': 'plot population pyramids by age for Chad using HDX data as an image', 'metadata': {'mem_type': 'memory', 'custom_id': '70d84687-302e-47ac-9019-28921bc20380'}}
#
#
# You are an AI judge that looks at matches for the user's request and decides if they are a match or not.
#
# You cannot choose more than ONE match.
#
# You have specific memories you can match on, as well as generic skills that might be what the user needs.
#
# For example, if the user want to plot a scatter plot of food prices in Uganda, the top hit would be a match on a
# memory like 'plot a scatter graph of prices in Uganda in the last 5 years. If a specific memory match
# like this doesn't exist, match on a generic skill that can be used with the user's input parameters, for example
# 'plot a scatter graph of prices in a country'.
#
# Key points to consider:
#
# - 'metadata' can relate to user questions about available data
# - If you user has a very general question, eg 'What data do you have' but the possible match is more specific, eg 'what data do you have for region X', it is not a match
# - 'Plot population pyramids' means the same as 'plot a pyramid plot'
#
# Examples of Matches:
#
# User intent: generate a line chart of Maize prices by year for 2013-2023 for Chad
# Match: plot a line chart of commodity prices monthly relative change for Chad from 2008-01-01 using HDX data as an image
# Reason: There is a general skill which can be used for the user's request
#
# User intent: plot population pyramids for chad
# Match: plot population pyramids for Chad
# Reason: The user asked for exactly this, sample plot, same country
#
# Examples that are NOT matches::
#
# User intent: plot a map of population by state in Haiti
# Match: I would like a plot of population by state in Mali
# Reason: The user asked for Haiti, not Mali
#
# User intent: give me a plot of population in Chad
# Match: plot population pyramids for Chad
# Reason: The user asked for a general plot of population but didn't specify a plot type
#
# The user asked for this:
#
# Give me a demographic overview of Chad
#
# Here are possible matches:
#
# 1. plot population pyramids by age for Chad using HDX data as an image
# 2. List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data
# 3. plot population pyramids by age for a country using HDX data as an image
# 4. List organizations in top 3 states by population in provided IPC Phase in a country, using HAPI data
# 5. provide the total population of a provided country using HDX data as text
# 6. plot a map of population by admin1 or admin2 for a country using HAPI data as an image
#
#
# Do any in the list match the user's intent?
#
# Please respond with a JSON file of format ...
#
# {
#     "answer": <yes or no>,
#     "reason": <content>,
#     "match_id": <The number of the matching row in the list. Set to '' if no match>
# }
# {'answer': 'no', 'reason': 'The user asked for a demographic overview of Chad, which is a broad request. None of the provided matches offer a comprehensive demographic overview. They either focus on specific aspects like population pyramids or organizations in certain states, or they are too general without specifying Chad.', 'match_id': ''}
# {'score': None, 'content': None, 'metadata': None}

# %%
test_evaluation.head(10)
# Out:
#                                             question  \
# 0  Which NGOs are active in the most food-insecur...
# 1  Can you show me the main humanitarian actors i...
# 2  What organizations are working in Chad's hunge...
# 3  Give me a rundown of NGOs in Chad's top 3 food...
# 4  Who's operating in Chad's most severe IPC Phas...
# 5  What's the NGO presence in Chad's highest food...
# 6  Show me the humanitarian landscape in Chad's t...
# 7  Which aid groups are tackling the worst hunger...
# 8  Breakdown of organizations in Chad's most food...
# 9  Who's responding to the top 3 hunger crises in...
#
#                                     intent as per db  result_legacy_match  \
# 0  List organizations in the top 3 states by popu...                 True
# 1  List organizations in the top 3 states by popu...                False
# 2  List organizations in the top 3 states by popu...                 True
# 3  List organizations in the top 3 states by popu...                 True
# 4  List organizations in the top 3 states by popu...                 True
# 5  List organizations in the top 3 states by popu...                 True
# 6  List organizations in the top 3 states by popu...                 True
# 7  List organizations in the top 3 states by popu...                 True
# 8  List organizations in the top 3 states by popu...                False
# 9  List organizations in the top 3 states by popu...                False
#
#                                result_legacy_details  result_hyde_match  \
# 0  {'score': 0.18325207183515335, 'content': 'Lis...               True
# 1  {'score': None, 'content': None, 'metadata': N...              False
# 2  {'score': 0.16283161418625058, 'content': 'Lis...               True
# 3  {'score': 0.17323503813325902, 'content': 'Lis...               True
# 4  {'score': 0.11493902028333902, 'content': 'Lis...               True
# 5  {'score': 0.1883432079313362, 'content': 'List...               True
# 6  {'score': 0.10655348222810246, 'content': 'Lis...               True
# 7  {'score': 0.14413258030399745, 'content': 'pro...               True
# 8  {'score': None, 'content': None, 'metadata': N...               True
# 9  {'score': None, 'content': None, 'metadata': N...               True
#
#                                  result_hyde_details
# 0  {'score': 0.19111473845472293, 'content': 'Lis...
# 1  {'score': None, 'content': None, 'metadata': N...
# 2  {'score': 0.17246860041556322, 'content': 'Lis...
# 3  {'score': 0.18710993467826798, 'content': 'Lis...
# 4  {'score': 0.13062333395662962, 'content': 'Lis...
# 5  {'score': 0.1943756787802643, 'content': 'List...
# 6  {'score': 0.1384226722775449, 'content': 'List...
# 7  {'score': 0.18831602202895603, 'content': 'Lis...
# 8  {'score': 0.18093756031897545, 'content': 'Lis...
# 9  {'score': 0.161081350011676, 'content': 'List ...

# %%
test_evaluation["result_legacy_details"].iloc[0]
# Out:
# {'score': 0.18325207183515335,
#  'content': 'List organizations in the top 3 states by population in IPC Phase 3+ in Chad, using HAPI data',
#  'metadata': {'mem_type': 'memory',
#   'custom_id': '038c84df-9cc4-432c-a9b9-0e0b784c5af0'}}

# %%
import ast

# Function to parse the string and extract values
def parse_content(row):
    # Ensure the row is a string
    if isinstance(row, dict):
        content_dict = row
    else:
        # Convert single quotes to double quotes for valid JSON
        json_str = row.replace("'", '"')
        # Parse the JSON string to a dictionary
        content_dict = json.loads(json_str)
    
    return pd.Series({
        'score': content_dict['score'],
        'content_text': content_dict['content'],
        'metadata': content_dict['metadata']
    })

# Apply the function to the 'content' column and create new columns for the extracted values
test_evaluation[['legacy_score', 'legacy_content_text', 'legacy_metadata']] = test_evaluation['result_legacy_details'].apply(parse_content)
# Apply the function to the 'content' column and create new columns for the extracted values
test_evaluation[['hyde_score', 'hyde_content_text', 'hyde_metadata']] = test_evaluation['result_hyde_details'].apply(parse_content)

# %%
test_evaluation.head(5)
# Out:
#                                             question  \
# 0  Which NGOs are active in the most food-insecur...
# 1  Can you show me the main humanitarian actors i...
# 2  What organizations are working in Chad's hunge...
# 3  Give me a rundown of NGOs in Chad's top 3 food...
# 4  Who's operating in Chad's most severe IPC Phas...
#
#                                     intent as per db  result_legacy_match  \
# 0  List organizations in the top 3 states by popu...                 True
# 1  List organizations in the top 3 states by popu...                False
# 2  List organizations in the top 3 states by popu...                 True
# 3  List organizations in the top 3 states by popu...                 True
# 4  List organizations in the top 3 states by popu...                 True
#
#                                result_legacy_details  result_hyde_match  \
# 0  {'score': 0.18325207183515335, 'content': 'Lis...               True
# 1  {'score': None, 'content': None, 'metadata': N...              False
# 2  {'score': 0.16283161418625058, 'content': 'Lis...               True
# 3  {'score': 0.17323503813325902, 'content': 'Lis...               True
# 4  {'score': 0.11493902028333902, 'content': 'Lis...               True
#
#                                  result_hyde_details  legacy_score  \
# 0  {'score': 0.19111473845472293, 'content': 'Lis...      0.183252
# 1  {'score': None, 'content': None, 'metadata': N...           NaN
# 2  {'score': 0.17246860041556322, 'content': 'Lis...      0.162832
# 3  {'score': 0.18710993467826798, 'content': 'Lis...      0.173235
# 4  {'score': 0.13062333395662962, 'content': 'Lis...      0.114939
#
#                                  legacy_content_text  \
# 0  List organizations in the top 3 states by popu...
# 1                                               None
# 2  List organizations in the top 3 states by popu...
# 3  List organizations in the top 3 states by popu...
# 4  List organizations in the top 3 states by popu...
#
#                                      legacy_metadata  hyde_score  \
# 0  {'mem_type': 'memory', 'custom_id': '038c84df-...    0.191115
# 1                                               None         NaN
# 2  {'mem_type': 'memory', 'custom_id': '038c84df-...    0.172469
# 3  {'mem_type': 'memory', 'custom_id': '038c84df-...    0.187110
# 4  {'mem_type': 'memory', 'custom_id': '038c84df-...    0.130623
#
#                                    hyde_content_text  \
# 0  List organizations in the top 3 states by popu...
# 1                                               None
# 2  List organizations in the top 3 states by popu...
# 3  List organizations in the top 3 states by popu...
# 4  List organizations in the top 3 states by popu...
#
#                                        hyde_metadata
# 0  {'mem_type': 'memory', 'custom_id': '038c84df-...
# 1                                               None
# 2  {'mem_type': 'memory', 'custom_id': '038c84df-...
# 3  {'mem_type': 'memory', 'custom_id': '038c84df-...
# 4  {'mem_type': 'memory', 'custom_id': '038c84df-...

# %%
len(test_evaluation[test_evaluation["intent as per db"] == test_evaluation["legacy_content_text"]])
# Out:
# 82

# %%
len(test_evaluation[test_evaluation["intent as per db"] == test_evaluation["hyde_content_text"]])
# Out:
# 84
